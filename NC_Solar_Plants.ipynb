# %% [markdown]
# <a href="https://colab.research.google.com/github/HankCaswell/SolarCompetitiveIntel/blob/main/NC_Solar_Plants.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir("/content/drive/My Drive/STAR/Data")
# !ls -l
# Out:
# Mounted at /content/drive
# total 1533
# -rw------- 1 root root 850537 Jan 29 20:48 plants.json
# -rw------- 1 root root 718664 Jan 21 23:54 uspvdb_v2_0_20240801.csv

# %%
import pandas as pd

# Load the JSON file into a pandas DataFrame.
df = pd.read_json('plants.json')

# Now you can work with the DataFrame 'df'. For example, to display the first few rows:
print(df.head())
# Out:
#    Plant Code                        Plant Name  Utility Code  \
# 0       62873  Carolina Poultry Power Farmville         62749
# 1        2727                     Marshall (NC)          5416
# 2        2721    James E. Rogers Energy Complex          5416
# 3        2718                         G G Allen          5416
# 4        6250                              Mayo          3046
#
#                   Utility Name         Plant Address Plant City  \
# 0       Carolina Poultry Power  8966 W Marlboro Road  Farmville
# 1   Duke Energy Carolinas, LLC     8320 East Hwy 150    Terrell
# 2   Duke Energy Carolinas, LLC   Duke Power Rd #1002  Cliffside
# 3   Duke Energy Carolinas, LLC    253 Plant Allen Rd    Belmont
# 4  Duke Energy Progress - (NC)     10660 Boston Road    Roxboro
#
#        Plant County Plant State  Plant Zip  Plant Latitude  Plant Longitude  \
# 0       Pitt County          NC      27828       35.591719       -77.614507
# 1    Catawba County          NC      28682       35.597500       -80.965800
# 2  Cleveland County          NC      28024       35.220000       -81.759400
# 3     Gaston County          NC      28012       35.189700       -81.012200
# 4     Person County          NC      27573       36.527800       -78.891700
#
#   Balancing Authority Code           Balancing Authority Name  \
# 0                     SEPA  Southeastern Power Administration
# 1                      DUK              Duke Energy Carolinas
# 2                      DUK              Duke Energy Carolinas
# 3                      DUK              Duke Energy Carolinas
# 4                     CPLE          Duke Energy Progress East
#
#    Annual Generation Plant Initial Operation Date Last Update  \
# 0             4005.0                   2019-09-00  2023-12-01
# 1          7310279.0                   1965-03-00  2024-10-01
# 2          5044478.0                   1972-06-00  2024-10-01
# 3           191646.0                   1957-06-00  2024-10-01
# 4           958720.0                   1983-03-00  2024-10-01
#
#                                           Fuel Types  \
# 0                           Agricultural By-Products
# 1        Bituminous Coal : 51.1%|Natural Gas : 48.9%
# 2        Bituminous Coal : 64.7%|Natural Gas : 35.1%
# 3  Bituminous Coal : 98.4%|Distillate Fuel Oil : ...
# 4  Bituminous Coal : 98.8%|Distillate Fuel Oil : ...
#
#                                            Plant URL  \
# 0  https://www.gridinfo.com/plant/carolina-poultr...
# 1    https://www.gridinfo.com/plant/marshall-nc/2727
# 2  https://www.gridinfo.com/plant/james-e-rogers-...
# 3      https://www.gridinfo.com/plant/g-g-allen/2718
# 4           https://www.gridinfo.com/plant/mayo/6250
#
#                                          Utility URL  \
# 0    https://www.gridinfo.com/carolina-poultry-power
# 1  https://www.gridinfo.com/duke-energy-carolinas...
# 2  https://www.gridinfo.com/duke-energy-carolinas...
# 3  https://www.gridinfo.com/duke-energy-carolinas...
# 4   https://www.gridinfo.com/duke-energy-progress-nc
#
#                              Balancing Authority URL
# 0  https://www.gridinfo.com/balancing-authority/s...
# 1  https://www.gridinfo.com/balancing-authority/d...
# 2  https://www.gridinfo.com/balancing-authority/d...
# 3  https://www.gridinfo.com/balancing-authority/d...
# 4  https://www.gridinfo.com/balancing-authority/d...

# %%
# prompt: I want to take the json file that I just accessed, and filter it only by "Fuel Types" and return a CSV of only the entries that use "Solar"

# Filter the DataFrame to include only rows where 'Fuel Types' contains 'Solar'.
solar_plants = df[df['Fuel Types'].str.contains('Solar', na=False)]

# Save the filtered data to a CSV file.
solar_plants.to_csv('solar_plants.csv', index=False)

# Download the CSV file.
from google.colab import files
files.download('solar_plants.csv')

# %%
import pandas as pd
import plotly.express as px

# Assuming 'solar_plants.csv' is in the current working directory
# If not, adjust the path accordingly.
df = pd.read_csv('solar_plants.csv')

# Create the scatter_mapbox plot
# The change is in the hover_data argument below
fig = px.scatter_mapbox(df,
                        lat="Plant Latitude",
                        lon="Plant Longitude",
                        hover_name="Plant Name",
                        hover_data=["Annual Generation", "Fuel Types", "Plant State"], # Changed "State" to "Plant State"
                        color="Annual Generation",  # Color points by Annual Generation
                        size="Annual Generation",  # Size points by Annual Generation
                        zoom=6,  # Adjust zoom level as needed
                        mapbox_style="carto-positron", # or open-street-map
                        center={"lat": 35.5, "lon": -79}, # Center map on North Carolina
                        width=800,  # Adjust width
                        height=600) # Adjust height


fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b9791b6d-4184-4a4a-b95c-03a0ace76eeb" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9791b6d-4184-4a4a-b95c-03a0ace76eeb")) {                    Plotly.newPlot(                        "b9791b6d-4184-4a4a-b95c-03a0ace76eeb",                        [{"customdata":[[14111.0,"Landfill Gas : 54.6%|Solar : 45.4%","NC"],[39628.0,"Natural Gas : 90.3%|Distillate Fuel Oil : 5.9%|Solar : 3.7%","NC"],[6114.0,"Solar","NC"],[9605.0,"Solar","NC"],[3332.0,"Solar","NC"],[3907.0,"Solar","NC"],[9878.0,"Solar","NC"],[9129.0,"Solar","NC"],[9052.0,"Solar","NC"],[8696.0,"Solar","NC"],[8599.0,"Solar","NC"],[9363.0,"Solar","NC"],[10295.0,"Solar","NC"],[8676.0,"Solar","NC"],[3956.0,"Solar","NC"],[9737.0,"Solar","NC"],[8751.0,"Solar","NC"],[9356.0,"Solar","NC"],[8756.0,"Solar","NC"],[7060.0,"Solar","NC"],[63090.0,"Solar","NC"],[5421.0,"Solar","NC"],[9668.0,"Solar","NC"],[9482.0,"Solar","NC"],[65806.0,"Solar","NC"],[9644.0,"Solar","NC"],[7022.0,"Solar","NC"],[9892.0,"Solar","NC"],[7001.0,"Solar","NC"],[9904.0,"Solar","NC"],[8099.0,"Solar","NC"],[8253.0,"Solar","NC"],[9422.0,"Solar","NC"],[114695.0,"Solar","NC"],[5853.0,"Solar","NC"],[9959.0,"Solar","NC"],[13225.0,"Solar","NC"],[8722.0,"Solar","NC"],[6382.0,"Solar","NC"],[9621.0,"Solar","NC"],[8038.0,"Solar","NC"],[9201.0,"Solar","NC"],[9031.0,"Solar","NC"],[10184.0,"Solar","NC"],[9634.0,"Solar","NC"],[9635.0,"Solar","NC"],[28304.0,"Solar","NC"],[9280.0,"Solar","NC"],[5965.0,"Solar","NC"],[10608.0,"Solar","NC"],[9728.0,"Solar","NC"],[2881.0,"Solar","NC"],[4261.0,"Solar","NC"],[8793.0,"Solar","NC"],[8645.0,"Solar","NC"],[28316.0,"Solar","NC"],[8254.0,"Solar","NC"],[8906.0,"Solar","NC"],[9754.0,"Solar","NC"],[3333.0,"Solar","NC"],[11053.0,"Solar","NC"],[7484.0,"Solar","NC"],[8377.0,"Solar","NC"],[128185.0,"Solar","NC"],[96182.0,"Solar","NC"],[8148.0,"Solar","NC"],[7587.0,"Solar","NC"],[8997.0,"Solar","NC"],[7516.0,"Solar","NC"],[5886.0,"Solar","NC"],[8611.0,"Solar","NC"],[8966.0,"Solar","NC"],[9156.0,"Solar","NC"],[9271.0,"Solar","NC"],[8100.0,"Solar","NC"],[2228.0,"Solar","NC"],[6205.0,"Solar","NC"],[8761.0,"Solar","NC"],[8992.0,"Solar","NC"],[6807.0,"Solar","NC"],[9021.0,"Solar","NC"],[9215.0,"Solar","NC"],[8753.0,"Solar","NC"],[8752.0,"Solar","NC"],[10786.0,"Solar","NC"],[9238.0,"Solar","NC"],[67065.0,"Solar","NC"],[8480.0,"Solar","NC"],[8913.0,"Solar","NC"],[8753.0,"Solar","NC"],[8176.0,"Solar","NC"],[5858.0,"Solar","NC"],[141115.0,"Solar","NC"],[2219.0,"Solar","NC"],[10455.0,"Solar","NC"],[2029.0,"Solar","NC"],[8905.0,"Solar","NC"],[5961.0,"Solar","NC"],[8538.0,"Solar","NC"],[10418.0,"Solar","NC"],[8821.0,"Solar","NC"],[9151.0,"Solar","NC"],[8901.0,"Solar","NC"],[8622.0,"Solar","NC"],[7438.0,"Solar","NC"],[81156.0,"Solar","NC"],[27623.0,"Solar","NC"],[5724.0,"Solar","NC"],[7692.0,"Solar","NC"],[10071.0,"Solar","NC"],[9013.0,"Solar","NC"],[3140.0,"Solar","NC"],[3124.0,"Solar","NC"],[8547.0,"Solar","NC"],[3349.0,"Solar","NC"],[3860.0,"Solar","NC"],[3410.0,"Solar","NC"],[3233.0,"Solar","NC"],[9459.0,"Solar","NC"],[99589.0,"Solar","NC"],[3334.0,"Solar","NC"],[8116.0,"Solar","NC"],[3365.0,"Solar","NC"],[3745.0,"Solar","NC"],[5552.0,"Solar","NC"],[9223.0,"Solar","NC"],[10135.0,"Solar","NC"],[8315.0,"Solar","NC"],[9377.0,"Solar","NC"],[28599.0,"Solar","NC"],[9649.0,"Solar","NC"],[3280.0,"Solar","NC"],[145736.0,"Solar","NC"],[6346.0,"Solar","NC"],[35815.0,"Solar","NC"],[3043.0,"Solar","NC"],[2555.0,"Solar","NC"],[20985.0,"Solar","NC"],[8642.0,"Solar","NC"],[31200.0,"Solar","NC"],[4992.0,"Solar","NC"],[19973.0,"Solar","NC"],[33448.0,"Solar","NC"],[4001.0,"Solar","NC"],[143864.0,"Solar","NC"],[5895.0,"Solar","NC"],[2642.0,"Solar","NC"],[8996.0,"Solar","NC"],[3910.0,"Solar","NC"],[8791.0,"Solar","NC"], ...

# %%
# prompt: That map looks good, I want to now be able to filter the points that are showing up on the map based on the column "Utility Name" which is in 'solarplants.csv'.  Additionally, I want to add a column to the data in 'solarplants.csv',  "Utility Type", which I would like to integrate from data stored in the folder we've been working out of called "powercompanies.json". Ideally, after a user has filtered by "Utility Type" and "Utility Name", I would like for them to be able to download a csv of the data that is displaying on the map.

from google.colab import drive
import os
import pandas as pd
from google.colab import files
import plotly.express as px
import json

drive.mount('/content/drive')

os.chdir("/content/drive/My Drive/STAR/Data")
# !ls -l

# Load the JSON file into a pandas DataFrame.
df = pd.read_json('plants.json')

# Filter for solar plants
solar_plants = df[df['Fuel Types'].str.contains('Solar', na=False)]
solar_plants.to_csv('solar_plants.csv', index=False)

# Load solar plant data and power company data
solar_df = pd.read_csv('solar_plants.csv')
with open('powercompanies.json', 'r') as f:
    power_companies = json.load(f)

# Convert the JSON data to a DataFrame
power_companies_df = pd.DataFrame(power_companies)

# Merge the two dataframes based on 'Utility Name' and 'Company Name'
solar_df = pd.merge(solar_df, power_companies_df[['Company Name', 'Utility Type']], left_on='Utility Name', right_on='Company Name', how='left')

# Drop the redundant 'Company Name' column
solar_df = solar_df.drop(columns=['Company Name'])

# Fill any NaN values in 'Utility Type' with 'Unknown'
solar_df['Utility Type'].fillna('Unknown', inplace=True)

# Create the scatter_mapbox plot
fig = px.scatter_mapbox(solar_df,
                        lat="Plant Latitude",
                        lon="Plant Longitude",
                        hover_name="Plant Name",
                        hover_data=["Annual Generation", "Fuel Types", "Plant State", "Utility Name", "Utility Type"],
                        color="Annual Generation",
                        size="Annual Generation",
                        zoom=6,
                        mapbox_style="carto-positron",
                        center={"lat": 35.5, "lon": -79},
                        width=800,
                        height=600)

fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# Add interactive filtering (requires ipywidgets)
import ipywidgets as widgets
from IPython.display import display

# Utility Name filter
utility_name_dropdown = widgets.Dropdown(
    options=solar_df['Utility Name'].unique().tolist(),
    value=solar_df['Utility Name'].unique().tolist()[0],
    description='Utility Name:'
)


# Utility Type filter
utility_type_dropdown = widgets.Dropdown(
    options=solar_df['Utility Type'].unique().tolist(),
    value=solar_df['Utility Type'].unique().tolist()[0],
    description='Utility Type:'
)


def update_map(change):
    selected_utility_name = utility_name_dropdown.value
    selected_utility_type = utility_type_dropdown.value

    filtered_df = solar_df[
        (solar_df['Utility Name'] == selected_utility_name) & (solar_df['Utility Type'] == selected_utility_type)
    ]

    new_fig = px.scatter_mapbox(filtered_df,
                        lat="Plant Latitude",
                        lon="Plant Longitude",
                        hover_name="Plant Name",
                        hover_data=["Annual Generation", "Fuel Types", "Plant State", "Utility Name", "Utility Type"],
                        color="Annual Generation",
                        size="Annual Generation",
                        zoom=6,
                        mapbox_style="carto-positron",
                        center={"lat": 35.5, "lon": -79},
                        width=800,
                        height=600)

    new_fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    new_fig.show()

    #Download button
    @widgets.interact(filename="filtered_data.csv")
    def download_csv(filename):
        filtered_df.to_csv(filename, index=False)
        files.download(filename)



utility_name_dropdown.observe(update_map, names='value')
utility_type_dropdown.observe(update_map, names='value')

display(utility_name_dropdown)
display(utility_type_dropdown)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# total 9015
# -rw------- 1 root root  268327 Jan 29 21:23 filtered_data.csv
# -rw------- 1 root root  850537 Jan 29 20:48 plants.json
# -rw------- 1 root root 7119234 Jan 29 21:04 powercompanies.json
# -rw------- 1 root root  273074 Jan 29 21:20 solar_plants.csv
# -rw------- 1 root root  718664 Jan 21 23:54 uspvdb_v2_0_20240801.csv
# <ipython-input-15-0cc15fdda5ca>:37: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e5e7a6bf-a10b-46b8-9e39-49bdef041427" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5e7a6bf-a10b-46b8-9e39-49bdef041427")) {                    Plotly.newPlot(                        "e5e7a6bf-a10b-46b8-9e39-49bdef041427",                        [{"customdata":[[14111.0,"Landfill Gas : 54.6%|Solar : 45.4%","NC","White Street Renewables LLC","Independent Power Producer"],[39628.0,"Natural Gas : 90.3%|Distillate Fuel Oil : 5.9%|Solar : 3.7%","NC","Fayetteville Public Works Commission","Municipally-Owned Utility"],[6114.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9605.0,"Solar","NC","Strata Manager, LLC","Independent Power Producer"],[3332.0,"Solar","NC","Heelstone Energy Holdings, LLC","Independent Power Producer"],[3907.0,"Solar","NC","SRE Utility Solar 1, LLC","Independent Power Producer"],[9878.0,"Solar","NC","Hemlock Solar LLC","Independent Power Producer"],[9129.0,"Solar","NC","Duke Energy Renewables Services","Independent Power Producer"],[9052.0,"Solar","NC","HXNAir Solar One LLC","Independent Power Producer"],[8696.0,"Solar","NC","Duke Energy Renewables Services","Independent Power Producer"],[8599.0,"Solar","NC","Strata Manager, LLC","Independent Power Producer"],[9363.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[10295.0,"Solar","NC","MN8 Energy LLC","Independent Power Producer"],[8676.0,"Solar","NC","USF Essex Lessor, LLC","Independent Power Producer"],[3956.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9737.0,"Solar","NC","Sol Systems","Independent Power Producer"],[8751.0,"Solar","NC","Capital Dynamics","Independent Power Producer"],[9356.0,"Solar","NC","Pine Valley Solar, LLC","Independent Power Producer"],[8756.0,"Solar","NC","Strata Manager, LLC","Independent Power Producer"],[7060.0,"Solar","NC","MN8 Energy LLC","Independent Power Producer"],[63090.0,"Solar","NC","MN8 Energy LLC","Independent Power Producer"],[5421.0,"Solar","NC","Altus Power America Management, LLC","Independent Power Producer"],[9668.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9482.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[65806.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9644.0,"Solar","NC","Sol Systems","Independent Power Producer"],[7022.0,"Solar","NC","MN8 Energy LLC","Independent Power Producer"],[9892.0,"Solar","NC","USF Essex Lessor, LLC","Independent Power Producer"],[7001.0,"Solar","NC","USF Essex Lessor, LLC","Independent Power Producer"],[9904.0,"Solar","NC","Sugar Run Solar, LLC","Independent Power Producer"],[8099.0,"Solar","NC","Robin Solar LLC","Unknown"],[8253.0,"Solar","NC","Cash Solar, LLC","Independent Power Producer"],[9422.0,"Solar","NC","Altus Power America Management, LLC","Independent Power Producer"],[114695.0,"Solar","NC","Dominion Renewable Energy","Independent Power Producer|Investor-Owned Utility"],[5853.0,"Solar","NC","SRE Utility Solar 1, LLC","Independent Power Producer"],[9959.0,"Solar","NC","Sol Systems","Independent Power Producer"],[13225.0,"Solar","NC","Sol Systems","Independent Power Producer"],[8722.0,"Solar","NC","Conetoe Solar, LLC","Independent Power Producer"],[6382.0,"Solar","NC","Strata Manager, LLC","Independent Power Producer"],[9621.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[8038.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9201.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9031.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[10184.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9634 ...
# Dropdown(description='Utility Name:', options=('White Street Renewables LLC', 'Fayetteville Public Works Commi…
# Dropdown(description='Utility Type:', options=('Independent Power Producer', 'Municipally-Owned Utility', 'Unk…

# %%
# prompt: Almost there, I need an option to filter only by utility type, that is, I want an option to show all under "utility name" while only looking at certain subsections of utility type

# Previous code remains the same up to the interactive filtering section

# Add interactive filtering (requires ipywidgets)

# Utility Type filter
utility_type_dropdown = widgets.Dropdown(
    options=solar_df['Utility Type'].unique().tolist(),
    value=solar_df['Utility Type'].unique().tolist()[0],
    description='Utility Type:'
)

def update_map(change):
    selected_utility_type = utility_type_dropdown.value
    filtered_df = solar_df[solar_df['Utility Type'] == selected_utility_type]

    #Update Utility Name dropdown based on the selected Utility Type
    utility_name_dropdown.options = filtered_df['Utility Name'].unique().tolist()
    if utility_name_dropdown.options:
      utility_name_dropdown.value = utility_name_dropdown.options[0]
    else:
      # Handle case where no utility names are available after filtering
      print("No utility names found for the selected utility type.")
      return

    new_fig = px.scatter_mapbox(filtered_df,
                        lat="Plant Latitude",
                        lon="Plant Longitude",
                        hover_name="Plant Name",
                        hover_data=["Annual Generation", "Fuel Types", "Plant State", "Utility Name", "Utility Type"],
                        color="Annual Generation",
                        size="Annual Generation",
                        zoom=6,
                        mapbox_style="carto-positron",
                        center={"lat": 35.5, "lon": -79},
                        width=800,
                        height=600)

    new_fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    new_fig.show()

    #Download button
    @widgets.interact(filename="filtered_data.csv")
    def download_csv(filename):
        filtered_df.to_csv(filename, index=False)
        files.download(filename)


# Utility Name filter (now dependent on Utility Type)
utility_name_dropdown = widgets.Dropdown(
    options=solar_df['Utility Name'].unique().tolist(),
    value=solar_df['Utility Name'].unique().tolist()[0],
    description='Utility Name:'
)

utility_type_dropdown.observe(update_map, names='value')
utility_name_dropdown.observe(update_map, names='value')

display(utility_type_dropdown)
display(utility_name_dropdown)
# Out:
# Dropdown(description='Utility Type:', options=('Independent Power Producer', 'Municipally-Owned Utility', 'Unk…
# Dropdown(description='Utility Name:', options=('White Street Renewables LLC', 'Fayetteville Public Works Commi…
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b94087ba-82a2-4c7a-bfa5-ae839f16fcb7" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b94087ba-82a2-4c7a-bfa5-ae839f16fcb7")) {                    Plotly.newPlot(                        "b94087ba-82a2-4c7a-bfa5-ae839f16fcb7",                        [{"customdata":[[14111.0,"Landfill Gas : 54.6%|Solar : 45.4%","NC","White Street Renewables LLC","Independent Power Producer"],[6114.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9605.0,"Solar","NC","Strata Manager, LLC","Independent Power Producer"],[3332.0,"Solar","NC","Heelstone Energy Holdings, LLC","Independent Power Producer"],[3907.0,"Solar","NC","SRE Utility Solar 1, LLC","Independent Power Producer"],[9878.0,"Solar","NC","Hemlock Solar LLC","Independent Power Producer"],[9129.0,"Solar","NC","Duke Energy Renewables Services","Independent Power Producer"],[9052.0,"Solar","NC","HXNAir Solar One LLC","Independent Power Producer"],[8696.0,"Solar","NC","Duke Energy Renewables Services","Independent Power Producer"],[8599.0,"Solar","NC","Strata Manager, LLC","Independent Power Producer"],[9363.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[10295.0,"Solar","NC","MN8 Energy LLC","Independent Power Producer"],[8676.0,"Solar","NC","USF Essex Lessor, LLC","Independent Power Producer"],[3956.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9737.0,"Solar","NC","Sol Systems","Independent Power Producer"],[8751.0,"Solar","NC","Capital Dynamics","Independent Power Producer"],[9356.0,"Solar","NC","Pine Valley Solar, LLC","Independent Power Producer"],[8756.0,"Solar","NC","Strata Manager, LLC","Independent Power Producer"],[7060.0,"Solar","NC","MN8 Energy LLC","Independent Power Producer"],[63090.0,"Solar","NC","MN8 Energy LLC","Independent Power Producer"],[5421.0,"Solar","NC","Altus Power America Management, LLC","Independent Power Producer"],[9668.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9482.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[65806.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9644.0,"Solar","NC","Sol Systems","Independent Power Producer"],[7022.0,"Solar","NC","MN8 Energy LLC","Independent Power Producer"],[9892.0,"Solar","NC","USF Essex Lessor, LLC","Independent Power Producer"],[7001.0,"Solar","NC","USF Essex Lessor, LLC","Independent Power Producer"],[9904.0,"Solar","NC","Sugar Run Solar, LLC","Independent Power Producer"],[8253.0,"Solar","NC","Cash Solar, LLC","Independent Power Producer"],[9422.0,"Solar","NC","Altus Power America Management, LLC","Independent Power Producer"],[5853.0,"Solar","NC","SRE Utility Solar 1, LLC","Independent Power Producer"],[9959.0,"Solar","NC","Sol Systems","Independent Power Producer"],[13225.0,"Solar","NC","Sol Systems","Independent Power Producer"],[8722.0,"Solar","NC","Conetoe Solar, LLC","Independent Power Producer"],[6382.0,"Solar","NC","Strata Manager, LLC","Independent Power Producer"],[9621.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[8038.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9201.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9031.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[10184.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9634.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9635.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9280.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[5965.0,"Solar","NC","Strata Manager, LLC","Independent Power Produce ...
# interactive(children=(Text(value='filtered_data.csv', description='filename'), Output()), _dom_classes=('widge…
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4783da7d-b330-46dd-a20b-011d5b95c1e1" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4783da7d-b330-46dd-a20b-011d5b95c1e1")) {                    Plotly.newPlot(                        "4783da7d-b330-46dd-a20b-011d5b95c1e1",                        [{"customdata":[[14111.0,"Landfill Gas : 54.6%|Solar : 45.4%","NC","White Street Renewables LLC","Independent Power Producer"],[6114.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9605.0,"Solar","NC","Strata Manager, LLC","Independent Power Producer"],[3332.0,"Solar","NC","Heelstone Energy Holdings, LLC","Independent Power Producer"],[3907.0,"Solar","NC","SRE Utility Solar 1, LLC","Independent Power Producer"],[9878.0,"Solar","NC","Hemlock Solar LLC","Independent Power Producer"],[9129.0,"Solar","NC","Duke Energy Renewables Services","Independent Power Producer"],[9052.0,"Solar","NC","HXNAir Solar One LLC","Independent Power Producer"],[8696.0,"Solar","NC","Duke Energy Renewables Services","Independent Power Producer"],[8599.0,"Solar","NC","Strata Manager, LLC","Independent Power Producer"],[9363.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[10295.0,"Solar","NC","MN8 Energy LLC","Independent Power Producer"],[8676.0,"Solar","NC","USF Essex Lessor, LLC","Independent Power Producer"],[3956.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9737.0,"Solar","NC","Sol Systems","Independent Power Producer"],[8751.0,"Solar","NC","Capital Dynamics","Independent Power Producer"],[9356.0,"Solar","NC","Pine Valley Solar, LLC","Independent Power Producer"],[8756.0,"Solar","NC","Strata Manager, LLC","Independent Power Producer"],[7060.0,"Solar","NC","MN8 Energy LLC","Independent Power Producer"],[63090.0,"Solar","NC","MN8 Energy LLC","Independent Power Producer"],[5421.0,"Solar","NC","Altus Power America Management, LLC","Independent Power Producer"],[9668.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9482.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[65806.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9644.0,"Solar","NC","Sol Systems","Independent Power Producer"],[7022.0,"Solar","NC","MN8 Energy LLC","Independent Power Producer"],[9892.0,"Solar","NC","USF Essex Lessor, LLC","Independent Power Producer"],[7001.0,"Solar","NC","USF Essex Lessor, LLC","Independent Power Producer"],[9904.0,"Solar","NC","Sugar Run Solar, LLC","Independent Power Producer"],[8253.0,"Solar","NC","Cash Solar, LLC","Independent Power Producer"],[9422.0,"Solar","NC","Altus Power America Management, LLC","Independent Power Producer"],[5853.0,"Solar","NC","SRE Utility Solar 1, LLC","Independent Power Producer"],[9959.0,"Solar","NC","Sol Systems","Independent Power Producer"],[13225.0,"Solar","NC","Sol Systems","Independent Power Producer"],[8722.0,"Solar","NC","Conetoe Solar, LLC","Independent Power Producer"],[6382.0,"Solar","NC","Strata Manager, LLC","Independent Power Producer"],[9621.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[8038.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9201.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9031.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[10184.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9634.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9635.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[9280.0,"Solar","NC","Cypress Creek Renewables","Independent Power Producer"],[5965.0,"Solar","NC","Strata Manager, LLC","Independent Power Produce ...
# interactive(children=(Text(value='filtered_data.csv', description='filename'), Output()), _dom_classes=('widge…
